# %%
# !python --version
# Out:
# Python 3.13.15

# %%
# !pip install fastapi uvicorn sqlalchemy asyncpg alembic pydantic pydantic-settings email-validator nest-asyncio httpx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 17.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-454a185d-5ec1-429f-9550-5483ffb96c1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-454a185d-5ec1-429f-9550-5483ffb96c1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'fastapi_users_products_crud.zip', 'sample_data']

# %%
import zipfile
import os

zip_path = "/content/fastapi_users_products_crud.zip"
extract_path = "/content"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP extracted successfully.")
# Out:
# ZIP extracted successfully.

# %%
import zipfile
import os

zip_path = "/content/fastapi_users_products_crud.zip"
extract_path = "/content"

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("ZIP extracted successfully.")
# Out:
# ZIP extracted successfully.

# %%
# %cd /content/fastapi_users_products_crud
# !pwd
# Out:
# /content/fastapi_users_products_crud
# /content/fastapi_users_products_crud

# %%
# !find . -maxdepth 3 -type f | sort
# Out:
# ./alembic/env.py
# ./alembic.ini
# ./alembic/script.py.mako
# ./alembic/versions/0001_create_users_products.py
# ./app/api/deps.py
# ./app/api/__init__.py
# ./app/core/config.py
# ./app/core/__init__.py
# ./app/crud/__init__.py
# ./app/crud/product.py
# ./app/crud/user.py
# ./app/db/base.py
# ./app/db/__init__.py
# ./app/db/session.py
# ./app/__init__.py
# ./app/main.py
# ./app/models/__init__.py
# ./app/models/product.py
# ./app/models/user.py
# ./app/schemas/__init__.py
# ./app/schemas/product.py
# ./app/schemas/user.py
# ./.env.example
# ./.gitignore
# ./README.md
# ./requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.52
#     Uninstalling SQLAlchemy-2.0.52:
#       Successfully uninstalled SQLAlchemy-2.0.52
# ...

# %%
# !pip check
# Out:
# ipython 7.34.0 requires jedi, which is not installed.

# %%
# !python -m compileall -q app

# %%
print("Python syntax check completed.")
# Out:
# Python syntax check completed.

# %%
# !cat .env.example
# Out:
# APP_NAME=Users & Products API
# DEBUG=true
# DATABASE_URL=postgresql+asyncpg://USER:PASSWORD@HOST/DATABASE?ssl=require

# %%
from getpass import getpass

database_url = getpass("Paste your Neon DATABASE_URL: ")

with open(".env", "w") as f:
    f.write(f"DATABASE_URL={database_url}\n")

print(".env created.")

# %%
from getpass import getpass

database_url = getpass("Paste your DATABASE_URL: ")

if database_url.startswith("postgresql://"):
    database_url = database_url.replace(
        "postgresql://",
        "postgresql+asyncpg://",
        1
    )

with open(".env", "w") as f:
    f.write(f"DATABASE_URL={database_url}\n")

print("DATABASE_URL configured successfully.")

# %%
import os
from dotenv import load_dotenv

load_dotenv()

url = os.getenv("DATABASE_URL")

if url:
    print("DATABASE_URL is configured.")
    print("Driver:", url.split("://")[0])
else:
    print("DATABASE_URL is missing.")

# %%
# !apt-get update -qq
# !apt-get install -y postgresql postgresql-contrib

# %%
# !psql --version

# %%
# !service postgresql start

# %%
# !service postgresql status

# %%
# !sudo -u postgres psql -c "CREATE DATABASE fastapi_db;"

# %%
# !sudo -u postgres psql -c "CREATE USER fastapi_user WITH PASSWORD 'fastapi_password';"

# %%
# !sudo -u postgres psql -c "GRANT ALL PRIVILEGES ON DATABASE fastapi_db TO fastapi_user;"

# %%
# !psql -h localhost -U fastapi_user -d fastapi_db -c "SELECT version();"

# %%
# %cd /content/fastapi_users_products_crud

# %%
with open(".env", "w") as f:
    f.write(
        "DATABASE_URL=postgresql+asyncpg://fastapi_user:"
        "fastapi_password@localhost:5432/fastapi_db\n"
    )

print(".env created successfully.")

# %%
# !pip install -r requirements.txt

# %%
# !pip install asyncpg psycopg2-binary python-dotenv

# %%
import asyncio
import asyncpg

async def test_database():
    conn = await asyncpg.connect(
        user="fastapi_user",
        password="fastapi_password",
        database="fastapi_db",
        host="localhost",
        port=5432
    )

    result = await conn.fetchval("SELECT 1")
    print("Database connection successful:", result)

    await conn.close()

await test_database()

# %%
# !alembic current

# %%
# !alembic history

# %%
# !alembic upgrade head

# %%
# !alembic current

# %%
# !psql -h localhost -U fastapi_user -d fastapi_db -c "\dt"

# %%
import subprocess
import time

process = subprocess.Popen(
    [
        "uvicorn",
        "app.main:app",
        "--host", "0.0.0.0",
        "--port", "8000"
    ],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True
)

time.sleep(3)

print("FastAPI server started.")
print("Process status:", process.poll())

# %%
import requests

response = requests.get("http://127.0.0.1:8000/")

print("Status:", response.status_code)
print("Response:", response.json())

# %%
response = requests.get("http://127.0.0.1:8000/health")

print("Status:", response.status_code)
print("Response:", response.json())

# %%
response = requests.get("http://127.0.0.1:8000/openapi.json")

print("Status:", response.status_code)

openapi = response.json()

print("\nAPI:", openapi["info"]["title"])
print("Version:", openapi["info"]["version"])

print("\nEndpoints:")

for path, methods in openapi["paths"].items():
    print(path, "->", ", ".join(methods.keys()))

# %%
user_data = {
    "name": "Naseer",
    "email": "naseer@example.com",
    "age": 25
}

response = requests.post(
    "http://127.0.0.1:8000/users/",
    json=user_datatry:
    process.terminate()
    process.wait(timeout=5)
except:
    pass

print("FastAPI stopped.")
)

print("Status:", response.status_code)
print("Response:", response.json())

user = response.json()
user_id = user["id"]

print("User ID:", user_id)

# %%
try:
    process.terminate()
    process.wait(timeout=5)
except:
    pass

print("FastAPI stopped.")

# %%
import subprocess
import time

process = subprocess.Popen(
    [
        "uvicorn",
        "app.main:app",
        "--host", "127.0.0.1",
        "--port", "8000"
    ],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True
)

time.sleep(3)

if process.poll() is not None:
    print("FASTAPI FAILED TO START")
    print(process.stdout.read())
else:
    print("FastAPI is running.")

# %%
user_data = {
    "name": "Naseer",
    "email": "naseer@example.com",
    "age": 25
}

response = requests.post(
    "http://127.0.0.1:8000/users/",
    json=user_data
)

print("Status:", response.status_code)
print("Content-Type:", response.headers.get("content-type"))
print("Response:")
print(response.text)

# %%
time.sleep(1)

output = ""

while True:
    line = process.stdout.readline()
    if not line:
        break
    output += line

print(output)

# %%
# !PGPASSWORD=fastapi_password psql \
-h localhost \
-U fastapi_user \
-d fastapi_db \
-c "\dt"

# %%
# !PGPASSWORD=fastapi_password psql \
-h localhost \
-U fastapi_user \
-d fastapi_db \
-c "SELECT current_database(), current_user;"

# %%
user_data = {
    "name": "Naseer",
    "email": "naseer@example.com",
    "age": 25
}

response = requests.post(
    "http://127.0.0.1:8000/users/",
    json=user_data
)

print("Status:", response.status_code)
print("Content-Type:", response.headers.get("content-type"))
print("Response:")
print(response.text)

# %%
time.sleep(1)

output = ""

while True:
    line = process.stdout.readline()
    if not line:
        break
    output += line

print(output)

# %%
update_user = {
    "name": "Naseer Shaik",
    "age": 26
}

response = requests.patch(
    f"http://127.0.0.1:8000/users/{user_id}",
    json=update_user
)

print("Status:", response.status_code)
print("Response:", response.json())

# %%
import requests

user_data = {
    "name": "Naseer",
    "email": "naseer@example.com",
    "age": 25
}

response = requests.post(
    "http://127.0.0.1:8000/users/",
    json=user_data
)

print("Status:", response.status_code)
print("Response:", response.text)

if response.status_code in [200, 201]:
    user = response.json()
    user_id = user["id"]
    print("User created successfully.")
    print("User ID:", user_id)
else:
    print("User creation failed.")

# %%
import requests

URL = "http://127.0.0.1:8000/users/"

user_data = {
    "name": "Naseer",
    "email": "naseer@example.com",
    "age": 25
}

response = requests.post(URL, json=user_data)

print("Status:", response.status_code)
print("Response:", response.text)

if response.status_code in (200, 201):
    try:
        user = response.json()
        user_id = user["id"]

        print("\n User created successfully!")
        print("User ID:", user_id)
        print("User:", user)

    except Exception as e:
        print("\n Server returned an unexpected response.")
        print("Error:", e)

else:
    print("\n User creation failed.")
    print("Status:", response.status_code)
    print("Server response:", response.text)

# %%
import requests

response = requests.get("http://127.0.0.1:8000/")

print("Status:", response.status_code)
print("Response:", response.text)

# %%
user_data = {
    "name": "Naseer",
    "email": "naseer2@example.com",
    "age": 25
}

response = requests.post(
    "http://127.0.0.1:8000/users/",
    json=user_data
)

print("Status:", response.status_code)
print("Response:", response.text)

if response.status_code in (200, 201):
    user = response.json()
    user_id = user["id"]
    print("✅ User ID:", user_id)
else:
    print("❌ User creation failed.")

# %%
time.sleep(1)

print(process.stdout.read())

# %%
mkdir fastapi-crud
cd fastapi-crud

mkdir app
mkdir app\models
mkdir app\schemas
mkdir app\routers

ni app\__init__.py
ni app\models\__init__.py
ni app\schemas\__init__.py
ni app\routers\__init__.py
ni app\main.py
ni app\database.py
ni app\models\user.py
ni app\models\product.py
ni app\schemas\user.py
ni app\schemas\product.py
ni app\routers\users.py
ni app\routers\products.py
ni .env
ni .gitignore
ni requirements.txt

# %%
# %%writefile main.py

import os

from fastapi import FastAPI, Depends, HTTPException, status
from pydantic import BaseModel, ConfigDict, EmailStr
from sqlalchemy import create_engine, String, Float, select
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column, Session, sessionmaker


# ============================================================
# DATABASE
# ============================================================

DATABASE_URL = os.environ["DATABASE_URL"]

engine = create_engine(
    DATABASE_URL,
    echo=True
)

SessionLocal = sessionmaker(
    bind=engine,
    autoflush=False,
    autocommit=False
)


class Base(DeclarativeBase):
    pass


def get_db():
    db = SessionLocal()

    try:
        yield db
    finally:
        db.close()


# ============================================================
# DATABASE MODELS
# ============================================================

class User(Base):

    __tablename__ = "users"

    id: Mapped[int] = mapped_column(
        primary_key=True,
        index=True
    )

    name: Mapped[str] = mapped_column(
        String(100),
        nullable=False
    )

    email: Mapped[str] = mapped_column(
        String(150),
        unique=True,
        nullable=False,
        index=True
    )


class Product(Base):

    __tablename__ = "products"

    id: Mapped[int] = mapped_column(
        primary_key=True,
        index=True
    )

    name: Mapped[str] = mapped_column(
        String(150),
        nullable=False
    )

    description: Mapped[str | None] = mapped_column(
        String(500),
        nullable=True
    )

    price: Mapped[float] = mapped_column(
        Float,
        nullable=False
    )

    quantity: Mapped[int] = mapped_column(
        default=0,
        nullable=False
    )


# Create tables in Neon PostgreSQL
Base.metadata.create_all(bind=engine)


# ============================================================
# PYDANTIC SCHEMAS
# ============================================================

class UserCreate(BaseModel):

    name: str
    email: EmailStr


class UserUpdate(BaseModel):

    name: str | None = None
    email: EmailStr | None = None


class UserResponse(BaseModel):

    id: int
    name: str
    email: EmailStr

    model_config = ConfigDict(
        from_attributes=True
    )


class ProductCreate(BaseModel):

    name: str
    description: str | None = None
    price: float
    quantity: int = 0


class ProductUpdate(BaseModel):

    name: str | None = None
    description: str | None = None
    price: float | None = None
    quantity: int | None = None


class ProductResponse(BaseModel):

    id: int
    name: str
    description: str | None
    price: float
    quantity: int

    model_config = ConfigDict(
        from_attributes=True
    )


# ============================================================
# FASTAPI APPLICATION
# ============================================================

app = FastAPI(
    title="Users and Products CRUD API",
    description="Functional CRUD APIs using FastAPI and Neon PostgreSQL",
    version="1.0.0"
)


# ============================================================
# ROOT
# ============================================================

@app.get("/")
def root():

    return {
        "message": "FastAPI CRUD API is running"
    }


# ============================================================
# USER CREATE
# ============================================================

@app.post(
    "/users",
    response_model=UserResponse,
    status_code=status.HTTP_201_CREATED,
    tags=["Users"]
)
def create_user(
    user_data: UserCreate,
    db: Session = Depends(get_db)
):

    existing_user = db.scalar(
        select(User).where(
            User.email == user_data.email
        )
    )

    if existing_user:

        raise HTTPException(
            status_code=400,
            detail="Email already registered"
        )

    user = User(
        name=user_data.name,
        email=user_data.email
    )

    db.add(user)
    db.commit()
    db.refresh(user)

    return user


# ============================================================
# USER READ ALL
# ============================================================

@app.get(
    "/users",
    response_model=list[UserResponse],
    tags=["Users"]
)
def get_users(
    db: Session = Depends(get_db)
):

    users = db.scalars(
        select(User)
    ).all()

    return users


# ============================================================
# USER READ ONE
# ============================================================

@app.get(
    "/users/{user_id}",
    response_model=UserResponse,
    tags=["Users"]
)
def get_user(
    user_id: int,
    db: Session = Depends(get_db)
):

    user = db.get(
        User,
        user_id
    )

    if user is None:

        raise HTTPException(
            status_code=404,
            detail="User not found"
        )

    return user


# ============================================================
# USER UPDATE
# ============================================================

@app.put(
    "/users/{user_id}",
    response_model=UserResponse,
    tags=["Users"]
)
def update_user(
    user_id: int,
    user_data: UserUpdate,
    db: Session = Depends(get_db)
):

    user = db.get(
        User,
        user_id
    )

    if user is None:

        raise HTTPException(
            status_code=404,
            detail="User not found"
        )

    if user_data.name is not None:

        user.name = user_data.name

    if user_data.email is not None:

        existing_user = db.scalar(
            select(User).where(
                User.email == user_data.email,
                User.id != user_id
            )
        )

        if existing_user:

            raise HTTPException(
                status_code=400,
                detail="Email already registered"
            )

        user.email = user_data.email

    db.commit()
    db.refresh(user)

    return user


# ============================================================
# USER DELETE
# ============================================================

@app.delete(
    "/users/{user_id}",
    status_code=status.HTTP_204_NO_CONTENT,
    tags=["Users"]
)
def delete_user(
    user_id: int,
    db: Session = Depends(get_db)
):

    user = db.get(
        User,
        user_id
    )

    if user is None:

        raise HTTPException(
            status_code=404,
            detail="User not found"
        )

    db.delete(user)
    db.commit()

    return None


# ============================================================
# PRODUCT CREATE
# ============================================================

@app.post(
    "/products",
    response_model=ProductResponse,
    status_code=status.HTTP_201_CREATED,
    tags=["Products"]
)
def create_product(
    product_data: ProductCreate,
    db: Session = Depends(get_db)
):

    product = Product(
        name=product_data.name,
        description=product_data.description,
        price=product_data.price,
        quantity=product_data.quantity
    )

    db.add(product)
    db.commit()
    db.refresh(product)

    return product


# ============================================================
# PRODUCT READ ALL
# ============================================================

@app.get(
    "/products",
    response_model=list[ProductResponse],
    tags=["Products"]
)
def get_products(
    db: Session = Depends(get_db)
):

    products = db.scalars(
        select(Product)
    ).all()

    return products


# ============================================================
# PRODUCT READ ONE
# ============================================================

@app.get(
    "/products/{product_id}",
    response_model=ProductResponse,
    tags=["Products"]
)
def get_product(
    product_id: int,
    db: Session = Depends(get_db)
):

    product = db.get(
        Product,
        product_id
    )

    if product is None:

        raise HTTPException(
            status_code=404,
            detail="Product not found"
        )

    return product


# ============================================================
# PRODUCT UPDATE
# ============================================================

@app.put(
    "/products/{product_id}",
    response_model=ProductResponse,
    tags=["Products"]
)
def update_product(
    product_id: int,
    product_data: ProductUpdate,
    db: Session = Depends(get_db)
):

    product = db.get(
        Product,
        product_id
    )

    if product is None:

        raise HTTPException(
            status_code=404,
            detail="Product not found"
        )

    if product_data.name is not None:

        product.name = product_data.name

    if product_data.description is not None:

        product.description = product_data.description

    if product_data.price is not None:

        product.price = product_data.price

    if product_data.quantity is not None:

        product.quantity = product_data.quantity

    db.commit()
    db.refresh(product)

    return product


# ============================================================
# PRODUCT DELETE
# ============================================================

@app.delete(
    "/products/{product_id}",
    status_code=status.HTTP_204_NO_CONTENT,
    tags=["Products"]
)
def delete_product(
    product_id: int,
    db: Session = Depends(get_db)
):

    product = db.get(
        Product,
        product_id
    )

    if product is None:

        raise HTTPException(
            status_code=404,
            detail="Product not found"
        )

    db.delete(product)
    db.commit()

    return None

# %%
import nest_asyncio
import threading
import uvicorn

nest_asyncio.apply()

def start_server():
    uvicorn.run(
        "main:app",
        host="0.0.0.0",
        port=8000,
        reload=False
    )

server_thread = threading.Thread(
    target=start_server,
    daemon=True
)

server_thread.start()

# %% [markdown]
# A running FastAPI service with validated Pydantic schemas and complete SQLAlchemy + Alembic CRUD operations against PostgreSQL

# %%
A running FastAPI service with validated Pydantic schemas and complete SQLAlchemy + Alembic CRUD operations against PostgreSQL

# %%
class Task(Base):
    __tablename__ = "tasks"

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str]

# %%
# !pip install sqlalchemy alembic psycopg2-binary python-dotenv

# %%
# !pip install sqlalchemy alembic asyncpg python-dotenv

# %%
from sqlalchemy import create_engine, String
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column


class Base(DeclarativeBase):
    pass


class Task(Base):
    __tablename__ = "tasks"

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str] = mapped_column(String(200))

# %%
from sqlalchemy import create_engine, String
from sqlalchemy.orm import DeclarativeBase, Mapped, mapped_column


class Base(DeclarativeBase):
    pass


class Task(Base):
    __tablename__ = "tasks"

    id: Mapped[int] = mapped_column(primary_key=True)
    title: Mapped[str] = mapped_column(String(200))

# %%
DATABASE_URL = "postgresql+psycopg2://USERNAME:PASSWORD@HOST/DATABASE?sslmode=require"

engine = create_engine(DATABASE_URL)
